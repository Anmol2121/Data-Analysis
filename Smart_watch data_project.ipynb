# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dailyActivity_merged.csv')

# %%
df
# Out:
#      Unnamed: 0          Id ActivityDate  TotalSteps  TotalDistance  \
# 0             0  1503960366    4/12/2016       13162       8.500000
# 1             1  1503960366    4/13/2016       10735       6.970000
# 2             2  1503960366    4/14/2016       10460       6.740000
# 3             3  1503960366    4/15/2016        9762       6.280000
# 4             4  1503960366    4/16/2016       12669       8.160000
# ..          ...         ...          ...         ...            ...
# 935         935  8877689391     5/8/2016       10686       8.110000
# 936         936  8877689391     5/9/2016       20226      18.250000
# 937         937  8877689391    5/10/2016       10733       8.150000
# 938         938  8877689391    5/11/2016       21420      19.559999
# 939         939  8877689391    5/12/2016        8064       6.120000
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0           8.500000                       0.0                1.88
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                940 non-null    int64
#  1   Id                        940 non-null    int64
#  2   ActivityDate              940 non-null    object
#  3   TotalSteps                940 non-null    int64
#  4   TotalDistance             940 non-null    float64
#  5   TrackerDistance           940 non-null    float64
#  6   LoggedActivitiesDistance  940 non-null    float64
#  7   VeryActiveDistance        940 non-null    float64
#  8   ModeratelyActiveDistance  940 non-null    float64
#  9   LightActiveDistance       940 non-null    float64
#  10  SedentaryActiveDistance   940 non-null    float64
#  11  VeryActiveMinutes         940 non-null    int64
#  12  FairlyActiveMinutes       940 non-null    int64
# ...

# %%
change = df['ActivityDate'] = pd.to_datetime(df['ActivityDate']).dt.date

# %%
change.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 940 entries, 0 to 939
# Series name: ActivityDate
# Non-Null Count  Dtype
# --------------  -----
# 940 non-null    object
# dtypes: object(1)
# memory usage: 7.5+ KB

# %%
group = df[['ActivityDate']]

# %%
group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ActivityDate  940 non-null    object
# dtypes: object(1)
# memory usage: 7.5+ KB

# %%
i_d = df.groupby('Id')

# %%
i_d1 = i_d.get_group(1503960366)

# %%
i_d1
# Out:
#     Unnamed: 0          Id ActivityDate  TotalSteps  TotalDistance  \
# 0            0  1503960366   2016-04-12       13162           8.50
# 1            1  1503960366   2016-04-13       10735           6.97
# 2            2  1503960366   2016-04-14       10460           6.74
# 3            3  1503960366   2016-04-15        9762           6.28
# 4            4  1503960366   2016-04-16       12669           8.16
# 5            5  1503960366   2016-04-17        9705           6.48
# 6            6  1503960366   2016-04-18       13019           8.59
# 7            7  1503960366   2016-04-19       15506           9.88
# 8            8  1503960366   2016-04-20       10544           6.68
# 9            9  1503960366   2016-04-21        9819           6.34
# 10          10  1503960366   2016-04-22       12764           8.13
# 11          11  1503960366   2016-04-23       14371           9.04
# 12          12  1503960366   2016-04-24       10039           6.41
# ...

# %%
unique = df['Id'].unique()

# %%
unique
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        3372868164, 3977333714, 4020332650, 4057192912, 4319703577,
#        4388161847, 4445114986, 4558609924, 4702921684, 5553957443,
#        5577150313, 6117666160, 6290855005, 6775888955, 6962181067,
#        7007744171, 7086361926, 8053475328, 8253242879, 8378563200,
#        8583815059, 8792009665, 8877689391], dtype=int64)

# %%
i_d2 = i_d.get_group(1624580081)

# %%
i_d2
# Out:
#     Unnamed: 0          Id ActivityDate  TotalSteps  TotalDistance  \
# 31          31  1624580081   2016-04-12        8163       5.310000
# 32          32  1624580081   2016-04-13        7007       4.550000
# 33          33  1624580081   2016-04-14        9107       5.920000
# 34          34  1624580081   2016-04-15        1510       0.980000
# 35          35  1624580081   2016-04-16        5370       3.490000
# 36          36  1624580081   2016-04-17        6175       4.060000
# 37          37  1624580081   2016-04-18       10536       7.410000
# 38          38  1624580081   2016-04-19        2916       1.900000
# 39          39  1624580081   2016-04-20        4974       3.230000
# 40          40  1624580081   2016-04-21        6349       4.130000
# 41          41  1624580081   2016-04-22        4026       2.620000
# 42          42  1624580081   2016-04-23        8538       5.550000
# 43          43  1624580081   2016-04-24        6076       3.950000
# ...

# %%
i_d3 = i_d.get_group(1644430081)
i_d4 = i_d.get_group(1844505072)
i_d5 = i_d.get_group(1927972279)
i_d6 = i_d.get_group(2022484408)
i_d7 = i_d.get_group(2026352035)
i_d8 = i_d.get_group(2320127002)

# %%
i_d8
# Out:
#      Unnamed: 0          Id ActivityDate  TotalSteps  TotalDistance  \
# 216         216  2320127002   2016-04-12       10725           7.49
# 217         217  2320127002   2016-04-13        7275           4.90
# 218         218  2320127002   2016-04-14        3973           2.68
# 219         219  2320127002   2016-04-15        5205           3.51
# 220         220  2320127002   2016-04-16        5057           3.41
# 221         221  2320127002   2016-04-17        6198           4.18
# 222         222  2320127002   2016-04-18        6559           4.42
# 223         223  2320127002   2016-04-19        5997           4.04
# 224         224  2320127002   2016-04-20        7192           4.85
# 225         225  2320127002   2016-04-21        3404           2.29
# 226         226  2320127002   2016-04-22        5583           3.76
# 227         227  2320127002   2016-04-23        5079           3.42
# 228         228  2320127002   2016-04-24        4165           2.81
# ...

# %%
dist = i_d1[['Id','ActivityDate','TotalSteps','TotalDistance','TrackerDistance','LoggedActivitiesDistance','VeryActiveDistance','ModeratelyActiveDistance',
     'LightActiveDistance','SedentaryActiveDistance']]

# %%
dist
# Out:
#             Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0   1503960366   2016-04-12       13162           8.50             8.50
# 1   1503960366   2016-04-13       10735           6.97             6.97
# 2   1503960366   2016-04-14       10460           6.74             6.74
# 3   1503960366   2016-04-15        9762           6.28             6.28
# 4   1503960366   2016-04-16       12669           8.16             8.16
# 5   1503960366   2016-04-17        9705           6.48             6.48
# 6   1503960366   2016-04-18       13019           8.59             8.59
# 7   1503960366   2016-04-19       15506           9.88             9.88
# 8   1503960366   2016-04-20       10544           6.68             6.68
# 9   1503960366   2016-04-21        9819           6.34             6.34
# 10  1503960366   2016-04-22       12764           8.13             8.13
# 11  1503960366   2016-04-23       14371           9.04             9.04
# ...

# %%
plt.figure(figsize=(15,10))

sns.barplot(x=dist.ActivityDate,y=dist.TotalSteps)
plt.title('ActivityDate [Total Step] 2016-04-12 To 2016-05-12',fontsize=22,fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %%
pie_data_1 = dist['ActivityDate'].iloc[0:7]
pie_data_2 = dist['TotalSteps'].iloc[0:7]
pie_data_3 = dist['TotalDistance'].iloc[0:7]

find_max = pie_data_2.max()
find_max
# Out:
# 13162

# %%
plt.figure(figsize=(50,6))
plt.subplot(1,2,1)
plt.pie(pie_data_2,labels=pie_data_1,shadow=True,autopct='%1.1f%%',startangle=90,explode=[0.04]*7)
plt.title('Total Steps in one-week [id = 1503960366]',fontweight='bold',fontsize=22)
plt.subplot(1,2,1)
plt.figure(figsize=(10,4))
sns.set_style('whitegrid')
sns.barplot(x=pie_data_3,y=pie_data_1)
plt.title('Total Distance (km) in one-week [id = 1503960366]',fontweight='bold',fontsize=22)
plt.ylabel('ActivityDate',fontweight='bold',fontsize=22)
plt.xlabel('TotalDistance',fontweight='bold',fontsize=22)
plt.xticks(rotation=45)
plt.show()

# %%
active1 = dist['LoggedActivitiesDistance'].iloc[0:7]
active2 = dist['VeryActiveDistance'].iloc[0:7]
active3 = dist['ModeratelyActiveDistance'].iloc[0:7]
active4 = dist['LightActiveDistance'].iloc[0:7]
active5 = dist['SedentaryActiveDistance'].iloc[0:7]

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.barplot(data=dist,x=pie_data_1,y=active1)
plt.title('LoggedActivitiesDistance in One-Week',fontweight='bold',fontsize=12,color='r')
plt.xticks(rotation=45)


plt.subplot(1,2,2)
sns.barplot(data=dist,x=pie_data_1,y=active2)
plt.title('VeryActiveDistance in One-Week',fontweight='bold',fontsize=12,color='g')
plt.xticks(rotation=45)
sns.set_style('ticks')

# %%
plt.subplot(1,2,1)
sns.barplot(data=dist,x=pie_data_1,y=active3)
plt.title('ModeratelyActiveDistance',fontweight = 'bold',fontsize=12,color='g')
plt.xticks(rotation=45)

plt.subplot(1,2,2)
sns.barplot(data=dist,x=pie_data_1,y=active4)
plt.title('LightActiveDistance',fontweight='bold',fontsize=12,color='g')
plt.xticks(rotation=45)
sns.set_style('ticks')

# %%
def total_step_data_in_one_month():
    cal_data1 = dist['ActivityDate'].iloc[0:19]
    cal_data2 = dist['TotalSteps'].iloc[0:19]
    cal_data3 = dist['TotalDistance'].iloc[0:19]
    cal_data4 = dist['LoggedActivitiesDistance'].iloc[0:19]
    cal_data5 = dist['VeryActiveDistance'].iloc[0:19]
    cal_data6 = dist['ModeratelyActiveDistance'].iloc[0:19]
    cal_data7 = dist['LightActiveDistance'].iloc[0:19]
    cal_data8 = dist['SedentaryActiveDistance'].iloc[0:19]
    
    total_step  = cal_data2
    total_dist = cal_data3
    total_LoggedActivitiesDistance = cal_data4
    total_VeryActiveDistance = cal_data5
    total_ModeratelyActiveDistance =  cal_data6
    total_LightActiveDistance = cal_data7
    
    id_ = df['Id'].iloc[1]
    print(f"\n\t\t\t\t\t\t\t\t\t[+]Id--{id_}\n\t\t================================================================================================\n")
    print(f"Total step {total_step.sum()}=======Total Distance {total_dist.sum()}======Logged Activities Distance {total_LoggedActivitiesDistance.sum()}\nVery Active Distance {total_VeryActiveDistance.sum()}=======Moderately Active Distance {total_ModeratelyActiveDistance.sum()}======Light Active Distance {total_LightActiveDistance.sum()}")
    

total_step_data_in_one_month()
# Out:
# 									[+]Id--1503960366
# ...
#
# Total step 238807=======Total Distance 153.92999982833865======Logged Activities Distance 0.0
# Very Active Distance 56.68000042438507=======Moderately Active Distance 14.05999992787839======Light Active Distance 83.09999990463257
